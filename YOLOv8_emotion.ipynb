# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 896.9/896.9 kB 45.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load model
model = YOLO('yolov8n.yaml')

# Train model on breed
result = model.train(data=("/content/drive/MyDrive/CMPE258_Project/emotion/data.yaml"), epochs=200)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")

# %%
import matplotlib.pyplot as plt
import cv2

results = model.predict(source="/content/drive/MyDrive/CMPE258_Project/emotion/images/pred/happy (100).jpg", show=True, save = True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /content/drive/MyDrive/CMPE258_Project/emotion/images/pred/happy (100).jpg: 640x640 1 Happy, 19.9ms
# Speed: 4.1ms preprocess, 19.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
predictions = model.predict(source="/content/drive/MyDrive/CMPE258_Project/emotion/images/pred", batch=16, save=True, save_dir="/content/drive/MyDrive/CMPE258_Project/emotion/results/predictions/")
# Out:
# image 1/40 /content/drive/MyDrive/CMPE258_Project/emotion/images/pred/angry (100).jpg: 640x640 1 Angry, 1 Relaxed, 4.4ms
# image 2/40 /content/drive/MyDrive/CMPE258_Project/emotion/images/pred/angry (91).jpg: 640x640 1 Angry, 4.4ms
# image 3/40 /content/drive/MyDrive/CMPE258_Project/emotion/images/pred/angry (92).jpg: 640x640 1 Angry, 2 Relaxeds, 4.4ms
# image 4/40 /content/drive/MyDrive/CMPE258_Project/emotion/images/pred/angry (93).jpg: 640x640 1 Angry, 4.4ms
# image 5/40 /content/drive/MyDrive/CMPE258_Project/emotion/images/pred/angry (94).jpg: 640x640 1 Angry, 4.4ms
# image 6/40 /content/drive/MyDrive/CMPE258_Project/emotion/images/pred/angry (95).jpg: 640x640 1 Angry, 4.4ms
# image 7/40 /content/drive/MyDrive/CMPE258_Project/emotion/images/pred/angry (96).jpg: 640x640 1 Angry, 4.4ms
# image 8/40 /content/drive/MyDrive/CMPE258_Project/emotion/images/pred/angry (97).jpg: 640x640 1 Angry, 4.4ms
# ...

# %%
import locale

# Check current locale
print(f"Current locale: {locale.getpreferredencoding()}")

# Set locale to UTF-8
# !sudo locale-gen en_US.UTF-8
# !sudo update-locale LC_ALL=en_US.UTF-8 LANG=en_US.UTF-8

# Verify locale change
print(f"New locale: {locale.getpreferredencoding()}")

# Now execute your mv command
# !mv /content/runs/detect/predict/ /content/drive/MyDrive/CMPE258_Project/emotion/results/predictions/
# Out:
# Current locale: ANSI_X3.4-1968
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-14-6674566a3165> in <cell line: 7>()
#       5
#       6 # Set locale to UTF-8
# ----> 7 get_ipython().system('sudo locale-gen en_US.UTF-8')
#       8 get_ipython().system('sudo update-locale LC_ALL=en_US.UTF-8 LANG=en_US.UTF-8')
#       9
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
# ...
